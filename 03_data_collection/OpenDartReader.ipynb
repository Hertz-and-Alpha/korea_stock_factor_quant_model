# %%
# !pip install opendartreader

# %%
import OpenDartReader

# %%
api_key = ''

# %%
dart = OpenDartReader(api_key)

# %%
dart.list('005930', start='2020')
# Out:
#    corp_code corp_name stock_code corp_cls            report_nm  \
# 0   00126380      삼성전자     005930        Y       최대주주등소유주식변동신고서
# 1   00126380      삼성전자     005930        Y     풍문또는보도에대한해명(미확정)
# 2   00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 3   00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 4   00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# ..       ...       ...        ...      ...                  ...
# 39  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 40  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 41  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 42  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 43  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
#
#           rcept_no  flr_nm  rcept_dt rm
# 0   20210906800409    삼성전자  20210906  유
# 1   20210906800238    삼성전자  20210906  유
# 2   20210902000252     허길영  20210902
# ...
